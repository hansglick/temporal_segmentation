# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import fun
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
n_plages = 4
n_events = 150
amplitude = 86400*15
pollution = 0.1

historic = fun.Events(None)
historic.Add_Simulation_Data(n_plages,n_events,amplitude,pollution)
historic.Print_Simulation_Data()
# Out:
# [75 10 63  0]
# [6.72259268 0.48392268 6.29501603 0.13319663]
# [0.2420132  0.47581618 0.22022761 0.06194301]

# %%
historic.Plot_Events(False)
